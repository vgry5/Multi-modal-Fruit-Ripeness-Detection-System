# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pathlib
import os
import PIL
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import Dense, Reshape, Flatten, Dropout, MaxPooling2D, Conv2D, GlobalAveragePooling2D
from keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam as LegacyAdam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
dataset_dir = pathlib.Path('/Users/admin/Downloads/DSGP/Data Set')
img_height, img_width = 180,180
batch_size = 16
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.1,
    subset="training",
    seed=123,
    label_mode="categorical",
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 10160 files belonging to 3 classes.
# Using 9144 files for training.

# %%
vali_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.1,
    subset="validation",
    seed=123,
    label_mode="categorical",
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 10160 files belonging to 3 classes.
# Using 1016 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Banana', 'Mango', 'Papaya']

# %%
efficientnet_model = Sequential()

pretrained_m =tf.keras.applications.EfficientNetB7(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(180,180,3),
    pooling=None,
    classes=3,
    classifier_activation="softmax",
)
for layer in pretrained_m.layers:
    layer.trainable = False
    
efficientnet_model.add(pretrained_m)
efficientnet_model.add(BatchNormalization())
efficientnet_model.add(GlobalAveragePooling2D())
efficientnet_model.add(Flatten())
efficientnet_model.add(Dense(256, activation='relu'))
efficientnet_model.add(Dropout(0.2))
efficientnet_model.add(Dense(3, activation='softmax'))

# %%
efficientnet_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb7 (Functional  (None, 6, 6, 2560)        64097687
#  )
#
#  batch_normalization_2 (Bat  (None, 6, 6, 2560)        10240
#  chNormalization)
#
#  module_wrapper_10 (ModuleW  (None, 2560)              0
#  rapper)
#
#  module_wrapper_11 (ModuleW  (None, 2560)              0
#  rapper)
#
#  module_wrapper_12 (ModuleW  (None, 256)               655616
#  rapper)
#
#  module_wrapper_13 (ModuleW  (None, 256)               0
#  rapper)
#
#  module_wrapper_14 (ModuleW  (None, 3)                 771
#  rapper)
#
# =================================================================
# Total params: 64764314 (247.06 MB)
# Trainable params: 661507 (2.52 MB)
# Non-trainable params: 64102807 (244.53 MB)
# _________________________________________________________________

# %%
efficientnet_model.compile(optimizer=LegacyAdam(learning_rate=0.01),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
epochs = 8
history = efficientnet_model.fit(
    train_ds,
    validation_data = vali_ds,
    epochs=epochs)
# Out:
# Epoch 1/8
# 572/572 [==============================] - 156s 249ms/step - loss: 1.0180 - accuracy: 0.9856 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/8
# 572/572 [==============================] - 120s 209ms/step - loss: 2.2021 - accuracy: 0.9937 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/8
# 572/572 [==============================] - 117s 205ms/step - loss: 2.5546 - accuracy: 0.9967 - val_loss: 3.3232 - val_accuracy: 0.9980
# Epoch 4/8
# 572/572 [==============================] - 121s 210ms/step - loss: 2.1321 - accuracy: 0.9976 - val_loss: 0.0383 - val_accuracy: 0.9990
# Epoch 5/8
# 572/572 [==============================] - 119s 208ms/step - loss: 1.3576 - accuracy: 0.9989 - val_loss: 0.1485 - val_accuracy: 0.9990
# Epoch 6/8
# 572/572 [==============================] - 156s 272ms/step - loss: 3.3336 - accuracy: 0.9974 - val_loss: 2.0089 - val_accuracy: 0.9980
# Epoch 7/8
# 572/572 [==============================] - 118s 206ms/step - loss: 1.2038 - accuracy: 0.9988 - val_loss: 2.0478 - val_accuracy: 0.9980
# Epoch 8/8
# 572/572 [==============================] - 119s 208ms/step - loss: 4.0244 - accuracy: 0.9970 - val_loss: 0.6174 - val_accuracy: 0.9990

# %%
fig = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.4,ymax=2)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
import cv2
image=cv2.imread('/Users/admin/Downloads/DSGP/Ripe-Yellow-Mango-500x375.png')
image_resized = cv2.resize(image, (img_height, img_width))
image=np.expand_dims(image_resized,axis=0)
print(image.shape)
# Out:
# (1, 180, 180, 3)

# %%
pred=efficientnet_model.predict(image)
print(pred)
# Out:
# 1/1 [==============================] - 0s 87ms/step
# [[0. 1. 0.]]

# %%
output_class = class_names[np.argmax(pred)]
print("The fruit is a", output_class)
# Out:
# The fruit is a Mango
