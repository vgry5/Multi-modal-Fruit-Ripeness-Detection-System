# %%
import cv2
import numpy as np
import os
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import Sequential, Model,load_model
from tensorflow.keras.optimizers.legacy import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform
import pathlib

# %%
dataset_dir = pathlib.Path('/Users/admin/Downloads/DSGP/Data Set')
img_height, img_width = 224,224
batch_size = 32
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    label_mode="categorical",
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 10160 files belonging to 3 classes.
# Using 8128 files for training.

# %%
vali_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.1,
    subset="validation",
    seed=123,
    label_mode="categorical",
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 10160 files belonging to 3 classes.
# Using 1016 files for validation.

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
base_model = ResNet50(input_shape=(224, 224, 3))

# %%
headModel = base_model.output
headModel = Flatten()(headModel)
headModel=Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel=Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel = Dense( 3,activation='softmax', name='fc3',kernel_initializer=glorot_uniform(seed=0))(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_3 (ZeroPadd  (None, 230, 230, 3)          0         ['input_4[0][0]']
#  ing2D)
#
#  conv1 (Conv2D)              (None, 112, 112, 64)         9472      ['zero_padding2d_3[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1[0][0]']
#  on)
#
#  activation_147 (Activation  (None, 112, 112, 64)         0         ['bn_conv1[0][0]']
#  )
#
#  max_pooling2d_3 (MaxPoolin  (None, 55, 55, 64)           0         ['activation_147[0][0]']
#  g2D)
#
#  res2a_branch2a (Conv2D)     (None, 55, 55, 64)           4160      ['max_pooling2d_3[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 55, 55, 64)           256       ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_148 (Activation  (None, 55, 55, 64)           0         ['bn2a_branch2a[0][0]']
#  )
#
#  res2a_branch2b (Conv2D)     (None, 55, 55, 64)           36928     ['activation_148[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 55, 55, 64)           256       ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_149 (Activation  (None, 55, 55, 64)           0         ['bn2a_branch2b[0][0]']
#  )
#
#  res2a_branch2c (Conv2D)     (None, 55, 55, 256)          16640     ['activation_149[0][0]']
#
#  res2a_branch1 (Conv2D)      (None, 55, 55, 256)          16640     ['max_pooling2d_3[0][0]']
#
#  bn2a_branch2c (BatchNormal  (None, 55, 55, 256)          1024      ['res2a_branch2c[0][0]']
#  ization)
#
#  bn2a_branch1 (BatchNormali  (None, 55, 55, 256)          1024      ['res2a_branch1[0][0]']
#  zation)
#
#  add_48 (Add)                (None, 55, 55, 256)          0         ['bn2a_branch2c[0][0]',
#                                                                      'bn2a_branch1[0][0]']
#
#  activation_150 (Activation  (None, 55, 55, 256)          0         ['add_48[0][0]']
#  )
#
#  res2b_branch2a (Conv2D)     (None, 55, 55, 64)           16448     ['activation_150[0][0]']
#
#  bn2b_branch2a (BatchNormal  (None, 55, 55, 64)           256       ['res2b_branch2a[0][0]']
#  ization)
#
#  activation_151 (Activation  (None, 55, 55, 64)           0         ['bn2b_branch2a[0][0]']
#  )
#
#  res2b_branch2b (Conv2D)     (None, 55, 55, 64)           36928     ['activation_151[0][0]']
#
#  bn2b_branch2b (BatchNormal  (None, 55, 55, 64)           256       ['res2b_branch2b[0][0]']
#  ization)
#
#  activation_152 (Activation  (None, 55, 55, 64)           0         ['bn2b_branch2b[0][0]']
#  )
#
#  res2b_branch2c (Conv2D)     (None, 55, 55, 256)          16640     ['activation_152[0][0]']
#
#  bn2b_branch2c (BatchNormal  (None, 55, 55, 256)          1024      ['res2b_branch2c[0][0]']
#  ization)
#
#  add_49 (Add)                (None, 55, 55, 256)          0         ['bn2b_branch2c[0][0]',
#                                                                      'activation_150[0][0]']
#
#  activation_153 (Activation  (None, 55, 55, 256)          0         ['add_49[0][0]']
#  )
#
#  res2c_branch2a (Conv2D)     (None, 55, 55, 64)           16448     ['activation_153[0][0]']
#
#  bn2c_branch2a (BatchNormal  (None, 55, 55, 64)           256       ['res2c_branch2a[0][0]']
#  ization)
#
#  activation_154 (Activation  (None, 55, 55, 64)           0         ['bn2c_branch2a[0][0]']
#  )
#
#  res2c_branch2b (Conv2D)     (None, 55, 55, 64)           36928     ['activation_154[0][0]']
#
#  bn2c_branch2b (BatchNormal  (None, 55, 55, 64)           256       ['res2c_branch2b[0][0]']
#  ization)
#
#  activation_155 (Activation  (None, 55, 55, 64)           0         ['bn2c_branch2b[0][0]']
#  )
#
#  res2c_branch2c (Conv2D)     (None, 55, 55, 256)          16640     ['activation_155[0][0]']
#
#  bn2c_branch2c (BatchNormal  (None, 55, 55, 256)          1024      ['res2c_branch2c[0][0]']
#  ization)
#
#  add_50 (Add)                (None, 55, 55, 256)          0         ['bn2c_branch2c[0][0]',
#                                                                      'activation_153[0][0]']
#
#  activation_156 (Activation  (None, 55, 55, 256)          0         ['add_50[0][0]']
#  )
#
#  res3a_branch2a (Conv2D)     (None, 28, 28, 128)          32896     ['activation_156[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 28, 28, 128)          512       ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_157 (Activation  (None, 28, 28, 128)          0         ['bn3a_branch2a[0][0]']
#  )
#
#  res3a_branch2b (Conv2D)     (None, 28, 28, 128)          147584    ['activation_157[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 28, 28, 128)          512       ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_158 (Activation  (None, 28, 28, 128)          0         ['bn3a_branch2b[0][0]']
#  )
#
#  res3a_branch2c (Conv2D)     (None, 28, 28, 512)          66048     ['activation_158[0][0]']
#
#  res3a_branch1 (Conv2D)      (None, 28, 28, 512)          131584    ['activation_156[0][0]']
#
#  bn3a_branch2c (BatchNormal  (None, 28, 28, 512)          2048      ['res3a_branch2c[0][0]']
#  ization)
#
#  bn3a_branch1 (BatchNormali  (None, 28, 28, 512)          2048      ['res3a_branch1[0][0]']
#  zation)
#
#  add_51 (Add)                (None, 28, 28, 512)          0         ['bn3a_branch2c[0][0]',
#                                                                      'bn3a_branch1[0][0]']
#
#  activation_159 (Activation  (None, 28, 28, 512)          0         ['add_51[0][0]']
#  )
#
#  res3b_branch2a (Conv2D)     (None, 28, 28, 128)          65664     ['activation_159[0][0]']
#
#  bn3b_branch2a (BatchNormal  (None, 28, 28, 128)          512       ['res3b_branch2a[0][0]']
#  ization)
#
#  activation_160 (Activation  (None, 28, 28, 128)          0         ['bn3b_branch2a[0][0]']
#  )
#
#  res3b_branch2b (Conv2D)     (None, 28, 28, 128)          147584    ['activation_160[0][0]']
#
#  bn3b_branch2b (BatchNormal  (None, 28, 28, 128)          512       ['res3b_branch2b[0][0]']
#  ization)
#
#  activation_161 (Activation  (None, 28, 28, 128)          0         ['bn3b_branch2b[0][0]']
#  )
#
#  res3b_branch2c (Conv2D)     (None, 28, 28, 512)          66048     ['activation_161[0][0]']
#
#  bn3b_branch2c (BatchNormal  (None, 28, 28, 512)          2048      ['res3b_branch2c[0][0]']
#  ization)
#
#  add_52 (Add)                (None, 28, 28, 512)          0         ['bn3b_branch2c[0][0]',
#                                                                      'activation_159[0][0]']
#
#  activation_162 (Activation  (None, 28, 28, 512)          0         ['add_52[0][0]']
#  )
#
#  res3c_branch2a (Conv2D)     (None, 28, 28, 128)          65664     ['activation_162[0][0]']
#
#  bn3c_branch2a (BatchNormal  (None, 28, 28, 128)          512       ['res3c_branch2a[0][0]']
#  ization)
#
#  activation_163 (Activation  (None, 28, 28, 128)          0         ['bn3c_branch2a[0][0]']
#  )
#
#  res3c_branch2b (Conv2D)     (None, 28, 28, 128)          147584    ['activation_163[0][0]']
#
#  bn3c_branch2b (BatchNormal  (None, 28, 28, 128)          512       ['res3c_branch2b[0][0]']
#  ization)
#
#  activation_164 (Activation  (None, 28, 28, 128)          0         ['bn3c_branch2b[0][0]']
#  )
#
#  res3c_branch2c (Conv2D)     (None, 28, 28, 512)          66048     ['activation_164[0][0]']
#
#  bn3c_branch2c (BatchNormal  (None, 28, 28, 512)          2048      ['res3c_branch2c[0][0]']
#  ization)
#
#  add_53 (Add)                (None, 28, 28, 512)          0         ['bn3c_branch2c[0][0]',
#                                                                      'activation_162[0][0]']
#
#  activation_165 (Activation  (None, 28, 28, 512)          0         ['add_53[0][0]']
#  )
#
#  res3d_branch2a (Conv2D)     (None, 28, 28, 128)          65664     ['activation_165[0][0]']
#
#  bn3d_branch2a (BatchNormal  (None, 28, 28, 128)          512       ['res3d_branch2a[0][0]']
#  ization)
#
#  activation_166 (Activation  (None, 28, 28, 128)          0         ['bn3d_branch2a[0][0]']
#  )
#
#  res3d_branch2b (Conv2D)     (None, 28, 28, 128)          147584    ['activation_166[0][0]']
#
#  bn3d_branch2b (BatchNormal  (None, 28, 28, 128)          512       ['res3d_branch2b[0][0]']
#  ization)
#
#  activation_167 (Activation  (None, 28, 28, 128)          0         ['bn3d_branch2b[0][0]']
#  )
#
#  res3d_branch2c (Conv2D)     (None, 28, 28, 512)          66048     ['activation_167[0][0]']
#
#  bn3d_branch2c (BatchNormal  (None, 28, 28, 512)          2048      ['res3d_branch2c[0][0]']
#  ization)
#
#  add_54 (Add)                (None, 28, 28, 512)          0         ['bn3d_branch2c[0][0]',
#                                                                      'activation_165[0][0]']
#
#  activation_168 (Activation  (None, 28, 28, 512)          0         ['add_54[0][0]']
#  )
#
#  res4a_branch2a (Conv2D)     (None, 14, 14, 256)          131328    ['activation_168[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 14, 14, 256)          1024      ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_169 (Activation  (None, 14, 14, 256)          0         ['bn4a_branch2a[0][0]']
#  )
#
#  res4a_branch2b (Conv2D)     (None, 14, 14, 256)          590080    ['activation_169[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 14, 14, 256)          1024      ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_170 (Activation  (None, 14, 14, 256)          0         ['bn4a_branch2b[0][0]']
#  )
#
#  res4a_branch2c (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_170[0][0]']
#
#  res4a_branch1 (Conv2D)      (None, 14, 14, 1024)         525312    ['activation_168[0][0]']
#
#  bn4a_branch2c (BatchNormal  (None, 14, 14, 1024)         4096      ['res4a_branch2c[0][0]']
#  ization)
#
#  bn4a_branch1 (BatchNormali  (None, 14, 14, 1024)         4096      ['res4a_branch1[0][0]']
#  zation)
#
#  add_55 (Add)                (None, 14, 14, 1024)         0         ['bn4a_branch2c[0][0]',
#                                                                      'bn4a_branch1[0][0]']
#
#  activation_171 (Activation  (None, 14, 14, 1024)         0         ['add_55[0][0]']
#  )
#
#  res4b_branch2a (Conv2D)     (None, 14, 14, 256)          262400    ['activation_171[0][0]']
#
#  bn4b_branch2a (BatchNormal  (None, 14, 14, 256)          1024      ['res4b_branch2a[0][0]']
#  ization)
#
#  activation_172 (Activation  (None, 14, 14, 256)          0         ['bn4b_branch2a[0][0]']
#  )
#
#  res4b_branch2b (Conv2D)     (None, 14, 14, 256)          590080    ['activation_172[0][0]']
#
#  bn4b_branch2b (BatchNormal  (None, 14, 14, 256)          1024      ['res4b_branch2b[0][0]']
#  ization)
#
#  activation_173 (Activation  (None, 14, 14, 256)          0         ['bn4b_branch2b[0][0]']
#  )
#
#  res4b_branch2c (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_173[0][0]']
#
#  bn4b_branch2c (BatchNormal  (None, 14, 14, 1024)         4096      ['res4b_branch2c[0][0]']
#  ization)
#
#  add_56 (Add)                (None, 14, 14, 1024)         0         ['bn4b_branch2c[0][0]',
#                                                                      'activation_171[0][0]']
#
#  activation_174 (Activation  (None, 14, 14, 1024)         0         ['add_56[0][0]']
#  )
#
#  res4c_branch2a (Conv2D)     (None, 14, 14, 256)          262400    ['activation_174[0][0]']
#
#  bn4c_branch2a (BatchNormal  (None, 14, 14, 256)          1024      ['res4c_branch2a[0][0]']
#  ization)
#
#  activation_175 (Activation  (None, 14, 14, 256)          0         ['bn4c_branch2a[0][0]']
#  )
#
#  res4c_branch2b (Conv2D)     (None, 14, 14, 256)          590080    ['activation_175[0][0]']
#
#  bn4c_branch2b (BatchNormal  (None, 14, 14, 256)          1024      ['res4c_branch2b[0][0]']
#  ization)
#
#  activation_176 (Activation  (None, 14, 14, 256)          0         ['bn4c_branch2b[0][0]']
#  )
#
#  res4c_branch2c (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_176[0][0]']
#
#  bn4c_branch2c (BatchNormal  (None, 14, 14, 1024)         4096      ['res4c_branch2c[0][0]']
#  ization)
#
#  add_57 (Add)                (None, 14, 14, 1024)         0         ['bn4c_branch2c[0][0]',
#                                                                      'activation_174[0][0]']
#
#  activation_177 (Activation  (None, 14, 14, 1024)         0         ['add_57[0][0]']
#  )
#
#  res4d_branch2a (Conv2D)     (None, 14, 14, 256)          262400    ['activation_177[0][0]']
#
#  bn4d_branch2a (BatchNormal  (None, 14, 14, 256)          1024      ['res4d_branch2a[0][0]']
#  ization)
#
#  activation_178 (Activation  (None, 14, 14, 256)          0         ['bn4d_branch2a[0][0]']
#  )
#
#  res4d_branch2b (Conv2D)     (None, 14, 14, 256)          590080    ['activation_178[0][0]']
#
#  bn4d_branch2b (BatchNormal  (None, 14, 14, 256)          1024      ['res4d_branch2b[0][0]']
#  ization)
#
#  activation_179 (Activation  (None, 14, 14, 256)          0         ['bn4d_branch2b[0][0]']
#  )
#
#  res4d_branch2c (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_179[0][0]']
#
#  bn4d_branch2c (BatchNormal  (None, 14, 14, 1024)         4096      ['res4d_branch2c[0][0]']
#  ization)
#
#  add_58 (Add)                (None, 14, 14, 1024)         0         ['bn4d_branch2c[0][0]',
#                                                                      'activation_177[0][0]']
#
#  activation_180 (Activation  (None, 14, 14, 1024)         0         ['add_58[0][0]']
#  )
#
#  res4e_branch2a (Conv2D)     (None, 14, 14, 256)          262400    ['activation_180[0][0]']
#
#  bn4e_branch2a (BatchNormal  (None, 14, 14, 256)          1024      ['res4e_branch2a[0][0]']
#  ization)
#
#  activation_181 (Activation  (None, 14, 14, 256)          0         ['bn4e_branch2a[0][0]']
#  )
#
#  res4e_branch2b (Conv2D)     (None, 14, 14, 256)          590080    ['activation_181[0][0]']
#
#  bn4e_branch2b (BatchNormal  (None, 14, 14, 256)          1024      ['res4e_branch2b[0][0]']
#  ization)
#
#  activation_182 (Activation  (None, 14, 14, 256)          0         ['bn4e_branch2b[0][0]']
#  )
#
#  res4e_branch2c (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_182[0][0]']
#
#  bn4e_branch2c (BatchNormal  (None, 14, 14, 1024)         4096      ['res4e_branch2c[0][0]']
#  ization)
#
#  add_59 (Add)                (None, 14, 14, 1024)         0         ['bn4e_branch2c[0][0]',
#                                                                      'activation_180[0][0]']
#
#  activation_183 (Activation  (None, 14, 14, 1024)         0         ['add_59[0][0]']
#  )
#
#  res4f_branch2a (Conv2D)     (None, 14, 14, 256)          262400    ['activation_183[0][0]']
#
#  bn4f_branch2a (BatchNormal  (None, 14, 14, 256)          1024      ['res4f_branch2a[0][0]']
#  ization)
#
#  activation_184 (Activation  (None, 14, 14, 256)          0         ['bn4f_branch2a[0][0]']
#  )
#
#  res4f_branch2b (Conv2D)     (None, 14, 14, 256)          590080    ['activation_184[0][0]']
#
#  bn4f_branch2b (BatchNormal  (None, 14, 14, 256)          1024      ['res4f_branch2b[0][0]']
#  ization)
#
#  activation_185 (Activation  (None, 14, 14, 256)          0         ['bn4f_branch2b[0][0]']
#  )
#
#  res4f_branch2c (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_185[0][0]']
#
#  bn4f_branch2c (BatchNormal  (None, 14, 14, 1024)         4096      ['res4f_branch2c[0][0]']
#  ization)
#
#  add_60 (Add)                (None, 14, 14, 1024)         0         ['bn4f_branch2c[0][0]',
#                                                                      'activation_183[0][0]']
#
#  activation_186 (Activation  (None, 14, 14, 1024)         0         ['add_60[0][0]']
#  )
#
#  res5a_branch2a (Conv2D)     (None, 7, 7, 512)            524800    ['activation_186[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 7, 7, 512)            2048      ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_187 (Activation  (None, 7, 7, 512)            0         ['bn5a_branch2a[0][0]']
#  )
#
#  res5a_branch2b (Conv2D)     (None, 7, 7, 512)            2359808   ['activation_187[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 7, 7, 512)            2048      ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_188 (Activation  (None, 7, 7, 512)            0         ['bn5a_branch2b[0][0]']
#  )
#
#  res5a_branch2c (Conv2D)     (None, 7, 7, 2048)           1050624   ['activation_188[0][0]']
#
#  res5a_branch1 (Conv2D)      (None, 7, 7, 2048)           2099200   ['activation_186[0][0]']
#
#  bn5a_branch2c (BatchNormal  (None, 7, 7, 2048)           8192      ['res5a_branch2c[0][0]']
#  ization)
#
#  bn5a_branch1 (BatchNormali  (None, 7, 7, 2048)           8192      ['res5a_branch1[0][0]']
#  zation)
#
#  add_61 (Add)                (None, 7, 7, 2048)           0         ['bn5a_branch2c[0][0]',
#                                                                      'bn5a_branch1[0][0]']
#
#  activation_189 (Activation  (None, 7, 7, 2048)           0         ['add_61[0][0]']
#  )
#
#  res5b_branch2a (Conv2D)     (None, 7, 7, 512)            1049088   ['activation_189[0][0]']
#
#  bn5b_branch2a (BatchNormal  (None, 7, 7, 512)            2048      ['res5b_branch2a[0][0]']
#  ization)
#
#  activation_190 (Activation  (None, 7, 7, 512)            0         ['bn5b_branch2a[0][0]']
#  )
#
#  res5b_branch2b (Conv2D)     (None, 7, 7, 512)            2359808   ['activation_190[0][0]']
#
#  bn5b_branch2b (BatchNormal  (None, 7, 7, 512)            2048      ['res5b_branch2b[0][0]']
#  ization)
#
#  activation_191 (Activation  (None, 7, 7, 512)            0         ['bn5b_branch2b[0][0]']
#  )
#
#  res5b_branch2c (Conv2D)     (None, 7, 7, 2048)           1050624   ['activation_191[0][0]']
#
#  bn5b_branch2c (BatchNormal  (None, 7, 7, 2048)           8192      ['res5b_branch2c[0][0]']
#  ization)
#
#  add_62 (Add)                (None, 7, 7, 2048)           0         ['bn5b_branch2c[0][0]',
#                                                                      'activation_189[0][0]']
#
#  activation_192 (Activation  (None, 7, 7, 2048)           0         ['add_62[0][0]']
#  )
#
#  res5c_branch2a (Conv2D)     (None, 7, 7, 512)            1049088   ['activation_192[0][0]']
#
#  bn5c_branch2a (BatchNormal  (None, 7, 7, 512)            2048      ['res5c_branch2a[0][0]']
#  ization)
#
#  activation_193 (Activation  (None, 7, 7, 512)            0         ['bn5c_branch2a[0][0]']
#  )
#
#  res5c_branch2b (Conv2D)     (None, 7, 7, 512)            2359808   ['activation_193[0][0]']
#
#  bn5c_branch2b (BatchNormal  (None, 7, 7, 512)            2048      ['res5c_branch2b[0][0]']
#  ization)
#
#  activation_194 (Activation  (None, 7, 7, 512)            0         ['bn5c_branch2b[0][0]']
#  )
#
#  res5c_branch2c (Conv2D)     (None, 7, 7, 2048)           1050624   ['activation_194[0][0]']
#
#  bn5c_branch2c (BatchNormal  (None, 7, 7, 2048)           8192      ['res5c_branch2c[0][0]']
#  ization)
#
#  add_63 (Add)                (None, 7, 7, 2048)           0         ['bn5c_branch2c[0][0]',
#                                                                      'activation_192[0][0]']
#
#  activation_195 (Activation  (None, 7, 7, 2048)           0         ['add_63[0][0]']
#  )
#
#  average_pooling2d_3 (Avera  (None, 4, 4, 2048)           0         ['activation_195[0][0]']
#  gePooling2D)
#
#  flatten_4 (Flatten)         (None, 32768)                0         ['average_pooling2d_3[0][0]']
#
#  fc1 (Dense)                 (None, 256)                  8388864   ['flatten_4[0][0]']
#
#  fc2 (Dense)                 (None, 128)                  32896     ['fc1[0][0]']
#
#  fc3 (Dense)                 (None, 3)                    387       ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 32009859 (122.11 MB)
# Trainable params: 31956739 (121.91 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
opt = SGD(learning_rate=1e-3, momentum=0.9)
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

# %%
es=EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=20)

# %%
H = model.fit(
    train_ds,
    epochs=100,
    verbose=1,
    validation_data=vali_ds
)
# Out:
# Epoch 1/100
# 2024-01-23 06:53:48.459181: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 254/254 [==============================] - 115s 427ms/step - loss: 6.2452 - accuracy: 0.8917 - val_loss: 7.4042 - val_accuracy: 0.8593
# Epoch 2/100
# 254/254 [==============================] - 108s 423ms/step - loss: 0.8306 - accuracy: 0.9580 - val_loss: 0.0032 - val_accuracy: 0.9980
# Epoch 3/100
# 254/254 [==============================] - 109s 426ms/step - loss: 0.1535 - accuracy: 0.9879 - val_loss: 0.0105 - val_accuracy: 0.9980
# Epoch 4/100
# 254/254 [==============================] - 109s 429ms/step - loss: 0.1143 - accuracy: 0.9932 - val_loss: 0.7162 - val_accuracy: 0.9360
# Epoch 5/100
# 254/254 [==============================] - 112s 442ms/step - loss: 0.1905 - accuracy: 0.9926 - val_loss: 2.7523e-04 - val_accuracy: 1.0000
# Epoch 6/100
# 254/254 [==============================] - 6954s 27s/step - loss: 0.4676 - accuracy: 0.9859 - val_loss: 1.4171 - val_accuracy: 0.9843
# Epoch 7/100
# 254/254 [==============================] - 111s 438ms/step - loss: 0.3041 - accuracy: 0.9953 - val_loss: 3.6934 - val_accuracy: 0.9478
# Epoch 8/100
# 254/254 [==============================] - 108s 425ms/step - loss: 1.3571 - accuracy: 0.9876 - val_loss: 0.2234 - val_accuracy: 0.9980
# Epoch 9/100
# 254/254 [==============================] - 109s 427ms/step - loss: 0.2022 - accuracy: 0.9975 - val_loss: 0.0091 - val_accuracy: 0.9990
# Epoch 10/100
# 254/254 [==============================] - 113s 442ms/step - loss: 0.0473 - accuracy: 0.9984 - val_loss: 1.0643 - val_accuracy: 0.9833
# Epoch 11/100
# 254/254 [==============================] - 113s 443ms/step - loss: 0.0793 - accuracy: 0.9995 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 12/100
# 254/254 [==============================] - 113s 444ms/step - loss: 0.0440 - accuracy: 0.9989 - val_loss: 0.0113 - val_accuracy: 0.9980
# Epoch 13/100
# 254/254 [==============================] - 112s 442ms/step - loss: 0.1001 - accuracy: 0.9993 - val_loss: 1.0659 - val_accuracy: 0.9862
# Epoch 14/100
# 254/254 [==============================] - 112s 442ms/step - loss: 0.3662 - accuracy: 0.9975 - val_loss: 10.1032 - val_accuracy: 0.9705
# Epoch 15/100
# 254/254 [==============================] - 113s 443ms/step - loss: 0.6659 - accuracy: 0.9964 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 16/100
# 254/254 [==============================] - 109s 430ms/step - loss: 0.0912 - accuracy: 0.9988 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 17/100
# 254/254 [==============================] - 108s 423ms/step - loss: 0.0881 - accuracy: 0.9988 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 18/100
# 254/254 [==============================] - 111s 436ms/step - loss: 0.0414 - accuracy: 0.9995 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 19/100
# 254/254 [==============================] - 113s 443ms/step - loss: 0.0219 - accuracy: 0.9996 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 20/100
# 125/254 [=============>................] - ETA: 54s - loss: 0.0047 - accuracy: 0.9998
