# %% [markdown]
#  # Fruit Ripeness Detection

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, BatchNormalization, MaxPool2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Model
import os
import matplotlib.pyplot as plt
import glob
import cv2
import seaborn as sns
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
TRAIN_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/train'
VAL_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/val'
TEST_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/test'

# %% [markdown]
# ### Initializing Image Size

# %%
IMAGE_SIZE = (240, 240)
BATCH_SIZE = 32

# %% [markdown]
# ### Initializing train, validation & test data

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(TRAIN_PATH,
                                                   target_size=(IMAGE_SIZE),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 5280 images belonging to 3 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(VAL_PATH,
                                                             target_size=(IMAGE_SIZE),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1320 images belonging to 3 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Over Ripe
# 1 : Ripe
# 2 : Unripe

# %% [markdown]
# ### Plot Images with labels

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
class_num = 3
image_w = 240
image_h = 240

# %% [markdown]
# ### Import model for Transfer Learning

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB1

inputs = layers.Input(shape=(image_w,image_h, 3))

outputs = EfficientNetB1(include_top=True, weights=None, classes=class_num)(inputs)
# Out:
# 2024-02-22 07:31:24.237198: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-02-22 07:31:24.237228: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-02-22 07:31:24.237231: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-02-22 07:31:24.237296: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-22 07:31:24.237322: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"] )

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 3)]     0
#
#  efficientnetb1 (Functional  (None, 3)                 6579082
#  )
#
# =================================================================
# Total params: 6579082 (25.10 MB)
# Trainable params: 6517027 (24.86 MB)
# Non-trainable params: 62055 (242.41 KB)
# _________________________________________________________________

# %%
def learning_rate_schedule(epoch, lr):
    if epoch < 3:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(learning_rate_schedule)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  
    patience=5,          
    restore_best_weights=True, 
)

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_eff.png',show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Train the model

# %%
hist = model.fit(train_generator, validation_data = validation_generator, epochs=50, verbose=2, callbacks = [lr_scheduler,early_stopping])
# Out:
# Epoch 1/50
# 2024-02-22 07:31:30.834418: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 165/165 - 119s - loss: 2.0718 - accuracy: 0.5634 - val_loss: 1.2563 - val_accuracy: 0.3333 - lr: 0.0010 - 119s/epoch - 718ms/step
# Epoch 2/50
# 165/165 - 102s - loss: 0.5765 - accuracy: 0.7898 - val_loss: 1.4382 - val_accuracy: 0.3333 - lr: 0.0010 - 102s/epoch - 616ms/step
# Epoch 3/50
# 165/165 - 101s - loss: 0.4809 - accuracy: 0.8352 - val_loss: 5.3198 - val_accuracy: 0.3333 - lr: 0.0010 - 101s/epoch - 611ms/step
# Epoch 4/50
# 165/165 - 99s - loss: 0.3164 - accuracy: 0.8803 - val_loss: 0.9115 - val_accuracy: 0.5394 - lr: 9.0484e-04 - 99s/epoch - 601ms/step
# Epoch 5/50
# 165/165 - 100s - loss: 0.2858 - accuracy: 0.8941 - val_loss: 0.3968 - val_accuracy: 0.8644 - lr: 8.1873e-04 - 100s/epoch - 608ms/step
# Epoch 6/50
# 165/165 - 101s - loss: 0.2515 - accuracy: 0.9047 - val_loss: 0.2696 - val_accuracy: 0.9015 - lr: 7.4082e-04 - 101s/epoch - 611ms/step
# Epoch 7/50
# 165/165 - 100s - loss: 0.2147 - accuracy: 0.9178 - val_loss: 0.2282 - val_accuracy: 0.9205 - lr: 6.7032e-04 - 100s/epoch - 608ms/step
# Epoch 8/50
# 165/165 - 101s - loss: 0.2041 - accuracy: 0.9235 - val_loss: 0.1911 - val_accuracy: 0.9318 - lr: 6.0653e-04 - 101s/epoch - 611ms/step
# Epoch 9/50
# 165/165 - 101s - loss: 0.2022 - accuracy: 0.9235 - val_loss: 0.1638 - val_accuracy: 0.9439 - lr: 5.4881e-04 - 101s/epoch - 612ms/step
# Epoch 10/50
# 165/165 - 100s - loss: 0.1943 - accuracy: 0.9239 - val_loss: 0.1386 - val_accuracy: 0.9515 - lr: 4.9659e-04 - 100s/epoch - 605ms/step
# Epoch 11/50
# 165/165 - 105s - loss: 0.1885 - accuracy: 0.9277 - val_loss: 0.1364 - val_accuracy: 0.9561 - lr: 4.4933e-04 - 105s/epoch - 638ms/step
# Epoch 12/50
# 165/165 - 108s - loss: 0.1764 - accuracy: 0.9311 - val_loss: 0.1647 - val_accuracy: 0.9432 - lr: 4.0657e-04 - 108s/epoch - 654ms/step
# Epoch 13/50
# 165/165 - 104s - loss: 0.1675 - accuracy: 0.9309 - val_loss: 0.2924 - val_accuracy: 0.8902 - lr: 3.6788e-04 - 104s/epoch - 632ms/step
# Epoch 14/50
# 165/165 - 100s - loss: 0.1645 - accuracy: 0.9348 - val_loss: 0.1331 - val_accuracy: 0.9583 - lr: 3.3287e-04 - 100s/epoch - 604ms/step
# Epoch 15/50
# 165/165 - 99s - loss: 0.1542 - accuracy: 0.9384 - val_loss: 0.1198 - val_accuracy: 0.9614 - lr: 3.0119e-04 - 99s/epoch - 599ms/step
# Epoch 16/50
# 165/165 - 99s - loss: 0.1600 - accuracy: 0.9388 - val_loss: 0.1578 - val_accuracy: 0.9500 - lr: 2.7253e-04 - 99s/epoch - 598ms/step
# Epoch 17/50
# 165/165 - 99s - loss: 0.1408 - accuracy: 0.9428 - val_loss: 0.1297 - val_accuracy: 0.9583 - lr: 2.4660e-04 - 99s/epoch - 598ms/step
# Epoch 18/50
# 165/165 - 99s - loss: 0.1338 - accuracy: 0.9449 - val_loss: 0.1210 - val_accuracy: 0.9636 - lr: 2.2313e-04 - 99s/epoch - 598ms/step
# Epoch 19/50
# 165/165 - 99s - loss: 0.1357 - accuracy: 0.9436 - val_loss: 0.1503 - val_accuracy: 0.9485 - lr: 2.0190e-04 - 99s/epoch - 598ms/step
# Epoch 20/50
# 165/165 - 100s - loss: 0.1354 - accuracy: 0.9458 - val_loss: 0.1132 - val_accuracy: 0.9674 - lr: 1.8268e-04 - 100s/epoch - 606ms/step
# Epoch 21/50
# 165/165 - 102s - loss: 0.1258 - accuracy: 0.9455 - val_loss: 0.0953 - val_accuracy: 0.9705 - lr: 1.6530e-04 - 102s/epoch - 618ms/step
# Epoch 22/50
# 165/165 - 99s - loss: 0.1250 - accuracy: 0.9479 - val_loss: 0.0928 - val_accuracy: 0.9758 - lr: 1.4957e-04 - 99s/epoch - 598ms/step
# Epoch 23/50
# 165/165 - 99s - loss: 0.1110 - accuracy: 0.9523 - val_loss: 0.0787 - val_accuracy: 0.9773 - lr: 1.3534e-04 - 99s/epoch - 598ms/step
# Epoch 24/50
# 165/165 - 99s - loss: 0.1178 - accuracy: 0.9477 - val_loss: 0.0976 - val_accuracy: 0.9674 - lr: 1.2246e-04 - 99s/epoch - 603ms/step
# Epoch 25/50
# 165/165 - 100s - loss: 0.1061 - accuracy: 0.9528 - val_loss: 0.0778 - val_accuracy: 0.9750 - lr: 1.1080e-04 - 100s/epoch - 604ms/step
# Epoch 26/50
# 165/165 - 99s - loss: 0.1053 - accuracy: 0.9527 - val_loss: 0.1172 - val_accuracy: 0.9621 - lr: 1.0026e-04 - 99s/epoch - 603ms/step
# Epoch 27/50
# 165/165 - 100s - loss: 0.0945 - accuracy: 0.9600 - val_loss: 0.0935 - val_accuracy: 0.9758 - lr: 9.0718e-05 - 100s/epoch - 603ms/step
# Epoch 28/50
# 165/165 - 100s - loss: 0.0945 - accuracy: 0.9576 - val_loss: 0.0637 - val_accuracy: 0.9803 - lr: 8.2085e-05 - 100s/epoch - 604ms/step
# Epoch 29/50
# 165/165 - 99s - loss: 0.0954 - accuracy: 0.9614 - val_loss: 0.0771 - val_accuracy: 0.9735 - lr: 7.4273e-05 - 99s/epoch - 602ms/step
# Epoch 30/50
# 165/165 - 99s - loss: 0.0889 - accuracy: 0.9614 - val_loss: 0.0704 - val_accuracy: 0.9765 - lr: 6.7205e-05 - 99s/epoch - 602ms/step
# Epoch 31/50
# 165/165 - 99s - loss: 0.0864 - accuracy: 0.9659 - val_loss: 0.0678 - val_accuracy: 0.9788 - lr: 6.0810e-05 - 99s/epoch - 602ms/step
# Epoch 32/50
# 165/165 - 99s - loss: 0.0879 - accuracy: 0.9638 - val_loss: 0.0619 - val_accuracy: 0.9841 - lr: 5.5023e-05 - 99s/epoch - 603ms/step
# Epoch 33/50
# 165/165 - 100s - loss: 0.0866 - accuracy: 0.9653 - val_loss: 0.0521 - val_accuracy: 0.9841 - lr: 4.9787e-05 - 100s/epoch - 603ms/step
# Epoch 34/50
# 165/165 - 99s - loss: 0.0712 - accuracy: 0.9674 - val_loss: 0.0498 - val_accuracy: 0.9864 - lr: 4.5049e-05 - 99s/epoch - 600ms/step
# Epoch 35/50
# 165/165 - 99s - loss: 0.0762 - accuracy: 0.9678 - val_loss: 0.0536 - val_accuracy: 0.9803 - lr: 4.0762e-05 - 99s/epoch - 599ms/step
# Epoch 36/50
# 165/165 - 99s - loss: 0.0764 - accuracy: 0.9680 - val_loss: 0.0502 - val_accuracy: 0.9848 - lr: 3.6883e-05 - 99s/epoch - 599ms/step
# Epoch 37/50
# 165/165 - 99s - loss: 0.0784 - accuracy: 0.9680 - val_loss: 0.0568 - val_accuracy: 0.9818 - lr: 3.3373e-05 - 99s/epoch - 601ms/step
# Epoch 38/50
# 165/165 - 99s - loss: 0.0687 - accuracy: 0.9722 - val_loss: 0.0559 - val_accuracy: 0.9818 - lr: 3.0197e-05 - 99s/epoch - 600ms/step
# Epoch 39/50
# 165/165 - 99s - loss: 0.0637 - accuracy: 0.9706 - val_loss: 0.0495 - val_accuracy: 0.9833 - lr: 2.7324e-05 - 99s/epoch - 601ms/step
# Epoch 40/50
# 165/165 - 99s - loss: 0.0700 - accuracy: 0.9701 - val_loss: 0.0471 - val_accuracy: 0.9856 - lr: 2.4723e-05 - 99s/epoch - 601ms/step
# Epoch 41/50
# 165/165 - 99s - loss: 0.0688 - accuracy: 0.9703 - val_loss: 0.0504 - val_accuracy: 0.9856 - lr: 2.2371e-05 - 99s/epoch - 600ms/step
# Epoch 42/50
# 165/165 - 99s - loss: 0.0663 - accuracy: 0.9748 - val_loss: 0.0511 - val_accuracy: 0.9818 - lr: 2.0242e-05 - 99s/epoch - 600ms/step
# Epoch 43/50
# 165/165 - 99s - loss: 0.0678 - accuracy: 0.9723 - val_loss: 0.0467 - val_accuracy: 0.9848 - lr: 1.8316e-05 - 99s/epoch - 600ms/step
# Epoch 44/50
# 165/165 - 99s - loss: 0.0631 - accuracy: 0.9746 - val_loss: 0.0480 - val_accuracy: 0.9871 - lr: 1.6573e-05 - 99s/epoch - 600ms/step
# Epoch 45/50
# 165/165 - 99s - loss: 0.0625 - accuracy: 0.9733 - val_loss: 0.0419 - val_accuracy: 0.9886 - lr: 1.4996e-05 - 99s/epoch - 601ms/step
# Epoch 46/50
# 165/165 - 99s - loss: 0.0587 - accuracy: 0.9750 - val_loss: 0.0417 - val_accuracy: 0.9902 - lr: 1.3569e-05 - 99s/epoch - 600ms/step
# Epoch 47/50
# 165/165 - 99s - loss: 0.0576 - accuracy: 0.9767 - val_loss: 0.0443 - val_accuracy: 0.9848 - lr: 1.2277e-05 - 99s/epoch - 600ms/step
# Epoch 48/50
# 165/165 - 99s - loss: 0.0614 - accuracy: 0.9731 - val_loss: 0.0415 - val_accuracy: 0.9894 - lr: 1.1109e-05 - 99s/epoch - 603ms/step
# Epoch 49/50
# 165/165 - 99s - loss: 0.0621 - accuracy: 0.9752 - val_loss: 0.0425 - val_accuracy: 0.9864 - lr: 1.0052e-05 - 99s/epoch - 603ms/step
# Epoch 50/50
# 165/165 - 99s - loss: 0.0601 - accuracy: 0.9758 - val_loss: 0.0416 - val_accuracy: 0.9879 - lr: 9.0953e-06 - 99s/epoch - 600ms/step

# %% [markdown]
# ### Train, Validation & Test accuracy from saved model

# %%
train_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

train_loss = hist.history['loss']
val_loss = hist.history['val_loss']

learning_rate = hist.history['lr']

# %% [markdown]
# ### Plot Accuracy & Loss graphs

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predictions on Test data

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(TEST_PATH,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMAGE_SIZE),
                                                 class_mode='categorical')
# Out:
# Found 660 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator)
# Out:
# 21/21 [==============================] - 6s 208ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %% [markdown]
# ### F1- Score, Precision & Recall

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 21/21 [==============================] - 4s 190ms/step - loss: 0.0787 - accuracy: 0.9697

# %% [markdown]
# ### Confusion Matrix

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.0787348672747612
# Test Accuracy: 0.9696969985961914

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(5,5))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    Over Ripe       0.97      0.95      0.96       220
#         Ripe       0.95      0.97      0.96       220
#       Unripe       0.99      1.00      0.99       220
#
#     accuracy                           0.97       660
#    macro avg       0.97      0.97      0.97       660
# weighted avg       0.97      0.97      0.97       660

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(4):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(TEST_PATH, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
