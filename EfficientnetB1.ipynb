# %% [markdown]
#  # Fruit Ripeness Detection

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, BatchNormalization, MaxPool2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Model
import os
import matplotlib.pyplot as plt
import glob
import cv2
import seaborn as sns
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
TRAIN_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/train'
VAL_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/val'
TEST_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/test'

# %% [markdown]
# ### Initializing Image Size

# %%
IMAGE_SIZE = (240, 240)
BATCH_SIZE = 32

# %% [markdown]
# ### Initializing train, validation & test data

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(TRAIN_PATH,
                                                   target_size=(IMAGE_SIZE),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 5280 images belonging to 3 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(VAL_PATH,
                                                             target_size=(IMAGE_SIZE),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1320 images belonging to 3 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Over Ripe
# 1 : Ripe
# 2 : Unripe

# %% [markdown]
# ### Plot Images with labels

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
class_num = 3
image_w = 240
image_h = 240

# %% [markdown]
# ### Import model for Transfer Learning

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB1

inputs = layers.Input(shape=(image_w,image_h, 3))

outputs = EfficientNetB1(include_top=True, weights=None, classes=class_num)(inputs)
# Out:
# 2024-03-03 10:55:26.102445: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-03-03 10:55:26.102477: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-03-03 10:55:26.102481: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-03-03 10:55:26.102521: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-03 10:55:26.102543: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"] )

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 3)]     0
#
#  efficientnetb1 (Functional  (None, 3)                 6579082
#  )
#
# =================================================================
# Total params: 6579082 (25.10 MB)
# Trainable params: 6517027 (24.86 MB)
# Non-trainable params: 62055 (242.41 KB)
# _________________________________________________________________

# %%
def learning_rate_schedule(epoch, lr):
    if epoch < 3:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(learning_rate_schedule)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  
    patience=5,          
    restore_best_weights=True, 
)

# %% [markdown]
# ### Train the model

# %%
hist = model.fit(train_generator, validation_data = validation_generator, epochs=50, verbose=2, callbacks = [lr_scheduler,early_stopping])
# Out:
# Epoch 1/50
# 2024-03-03 10:55:32.292239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 165/165 - 117s - loss: 1.8843 - accuracy: 0.5528 - val_loss: 2.2074 - val_accuracy: 0.3333 - lr: 0.0010 - 117s/epoch - 712ms/step
# Epoch 2/50
# 165/165 - 101s - loss: 0.5906 - accuracy: 0.7953 - val_loss: 1.8078 - val_accuracy: 0.3333 - lr: 0.0010 - 101s/epoch - 609ms/step
# Epoch 3/50
# 165/165 - 99s - loss: 0.3660 - accuracy: 0.8585 - val_loss: 4.9859 - val_accuracy: 0.3333 - lr: 0.0010 - 99s/epoch - 603ms/step
# Epoch 4/50
# 165/165 - 99s - loss: 0.2823 - accuracy: 0.8883 - val_loss: 1.4062 - val_accuracy: 0.3576 - lr: 9.0484e-04 - 99s/epoch - 599ms/step
# Epoch 5/50
# 165/165 - 99s - loss: 0.2511 - accuracy: 0.9030 - val_loss: 0.4872 - val_accuracy: 0.7561 - lr: 8.1873e-04 - 99s/epoch - 602ms/step
# Epoch 6/50
# 165/165 - 99s - loss: 0.2622 - accuracy: 0.9017 - val_loss: 0.1692 - val_accuracy: 0.9439 - lr: 7.4082e-04 - 99s/epoch - 600ms/step
# Epoch 7/50
# 165/165 - 100s - loss: 0.2231 - accuracy: 0.9133 - val_loss: 0.4943 - val_accuracy: 0.7485 - lr: 6.7032e-04 - 100s/epoch - 604ms/step
# Epoch 8/50
# 165/165 - 100s - loss: 0.2011 - accuracy: 0.9278 - val_loss: 0.2710 - val_accuracy: 0.9258 - lr: 6.0653e-04 - 100s/epoch - 606ms/step
# Epoch 9/50
# 165/165 - 99s - loss: 0.2193 - accuracy: 0.9161 - val_loss: 0.6708 - val_accuracy: 0.7902 - lr: 5.4881e-04 - 99s/epoch - 598ms/step
# Epoch 10/50
# 165/165 - 99s - loss: 0.2153 - accuracy: 0.9231 - val_loss: 0.1350 - val_accuracy: 0.9515 - lr: 4.9659e-04 - 99s/epoch - 599ms/step
# Epoch 11/50
# 165/165 - 99s - loss: 0.1878 - accuracy: 0.9258 - val_loss: 0.1685 - val_accuracy: 0.9432 - lr: 4.4933e-04 - 99s/epoch - 598ms/step
# Epoch 12/50
# 165/165 - 99s - loss: 0.1820 - accuracy: 0.9326 - val_loss: 0.3953 - val_accuracy: 0.7871 - lr: 4.0657e-04 - 99s/epoch - 598ms/step
# Epoch 13/50
# 165/165 - 99s - loss: 0.1662 - accuracy: 0.9362 - val_loss: 0.1254 - val_accuracy: 0.9606 - lr: 3.6788e-04 - 99s/epoch - 599ms/step
# Epoch 14/50
# 165/165 - 99s - loss: 0.1533 - accuracy: 0.9396 - val_loss: 0.2155 - val_accuracy: 0.9129 - lr: 3.3287e-04 - 99s/epoch - 599ms/step
# Epoch 15/50
# 165/165 - 99s - loss: 0.1606 - accuracy: 0.9371 - val_loss: 0.1354 - val_accuracy: 0.9606 - lr: 3.0119e-04 - 99s/epoch - 598ms/step
# Epoch 16/50
# 165/165 - 99s - loss: 0.1369 - accuracy: 0.9447 - val_loss: 0.1570 - val_accuracy: 0.9492 - lr: 2.7253e-04 - 99s/epoch - 598ms/step
# Epoch 17/50
# 165/165 - 99s - loss: 0.1309 - accuracy: 0.9453 - val_loss: 0.1175 - val_accuracy: 0.9561 - lr: 2.4660e-04 - 99s/epoch - 599ms/step
# Epoch 18/50
# 165/165 - 99s - loss: 0.1372 - accuracy: 0.9443 - val_loss: 0.1695 - val_accuracy: 0.9409 - lr: 2.2313e-04 - 99s/epoch - 598ms/step
# Epoch 19/50
# 165/165 - 99s - loss: 0.1244 - accuracy: 0.9481 - val_loss: 0.1196 - val_accuracy: 0.9689 - lr: 2.0190e-04 - 99s/epoch - 598ms/step
# Epoch 20/50
# 165/165 - 99s - loss: 0.1203 - accuracy: 0.9479 - val_loss: 0.1051 - val_accuracy: 0.9667 - lr: 1.8268e-04 - 99s/epoch - 599ms/step
# Epoch 21/50
# 165/165 - 99s - loss: 0.1067 - accuracy: 0.9553 - val_loss: 0.1161 - val_accuracy: 0.9591 - lr: 1.6530e-04 - 99s/epoch - 598ms/step
# Epoch 22/50
# 165/165 - 99s - loss: 0.1137 - accuracy: 0.9523 - val_loss: 0.1555 - val_accuracy: 0.9333 - lr: 1.4957e-04 - 99s/epoch - 598ms/step
# Epoch 23/50
# 165/165 - 99s - loss: 0.1115 - accuracy: 0.9517 - val_loss: 0.1028 - val_accuracy: 0.9621 - lr: 1.3534e-04 - 99s/epoch - 598ms/step
# Epoch 24/50
# 165/165 - 99s - loss: 0.1089 - accuracy: 0.9511 - val_loss: 0.0829 - val_accuracy: 0.9742 - lr: 1.2246e-04 - 99s/epoch - 598ms/step
# Epoch 25/50
# 165/165 - 99s - loss: 0.0977 - accuracy: 0.9557 - val_loss: 0.1061 - val_accuracy: 0.9629 - lr: 1.1080e-04 - 99s/epoch - 600ms/step
# Epoch 26/50
# 165/165 - 99s - loss: 0.1003 - accuracy: 0.9557 - val_loss: 0.1454 - val_accuracy: 0.9432 - lr: 1.0026e-04 - 99s/epoch - 601ms/step
# Epoch 27/50
# 165/165 - 99s - loss: 0.0968 - accuracy: 0.9568 - val_loss: 0.1591 - val_accuracy: 0.9280 - lr: 9.0718e-05 - 99s/epoch - 599ms/step
# Epoch 28/50
# 165/165 - 99s - loss: 0.0856 - accuracy: 0.9619 - val_loss: 0.1241 - val_accuracy: 0.9583 - lr: 8.2085e-05 - 99s/epoch - 597ms/step
# Epoch 29/50
# 165/165 - 99s - loss: 0.0892 - accuracy: 0.9604 - val_loss: 0.0818 - val_accuracy: 0.9742 - lr: 7.4273e-05 - 99s/epoch - 598ms/step
# Epoch 30/50
# 165/165 - 99s - loss: 0.0877 - accuracy: 0.9629 - val_loss: 0.1187 - val_accuracy: 0.9576 - lr: 6.7205e-05 - 99s/epoch - 597ms/step
# Epoch 31/50
# 165/165 - 99s - loss: 0.0948 - accuracy: 0.9604 - val_loss: 0.0751 - val_accuracy: 0.9720 - lr: 6.0810e-05 - 99s/epoch - 598ms/step
# Epoch 32/50
# 165/165 - 99s - loss: 0.0905 - accuracy: 0.9621 - val_loss: 0.1239 - val_accuracy: 0.9462 - lr: 5.5023e-05 - 99s/epoch - 599ms/step
# Epoch 33/50
# 165/165 - 99s - loss: 0.0800 - accuracy: 0.9657 - val_loss: 0.0756 - val_accuracy: 0.9712 - lr: 4.9787e-05 - 99s/epoch - 599ms/step
# Epoch 34/50
# 165/165 - 99s - loss: 0.0920 - accuracy: 0.9636 - val_loss: 0.0796 - val_accuracy: 0.9712 - lr: 4.5049e-05 - 99s/epoch - 598ms/step
# Epoch 35/50
# 165/165 - 99s - loss: 0.0771 - accuracy: 0.9646 - val_loss: 0.1053 - val_accuracy: 0.9553 - lr: 4.0762e-05 - 99s/epoch - 598ms/step
# Epoch 36/50
# 165/165 - 99s - loss: 0.0724 - accuracy: 0.9648 - val_loss: 0.1094 - val_accuracy: 0.9576 - lr: 3.6883e-05 - 99s/epoch - 598ms/step

# %% [markdown]
# ### Train, Validation & Test accuracy from saved model

# %%
train_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

train_loss = hist.history['loss']
val_loss = hist.history['val_loss']

learning_rate = hist.history['lr']

# %% [markdown]
# ### Plot Accuracy & Loss graphs

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predictions on Test data

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(TEST_PATH,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMAGE_SIZE),
                                                 class_mode='categorical')
# Out:
# Found 660 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator)
# Out:
# 21/21 [==============================] - 6s 200ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %% [markdown]
# ### F1- Score, Precision & Recall

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 21/21 [==============================] - 4s 191ms/step - loss: 0.0916 - accuracy: 0.9606

# %% [markdown]
# ### Confusion Matrix

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.09160056710243225
# Test Accuracy: 0.960606038570404

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(5,5))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    Over Ripe       0.93      0.96      0.95       220
#         Ripe       0.97      0.92      0.94       220
#       Unripe       0.99      1.00      0.99       220
#
#     accuracy                           0.96       660
#    macro avg       0.96      0.96      0.96       660
# weighted avg       0.96      0.96      0.96       660

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(4):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(TEST_PATH, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()

# %%
tf.keras.models.save_model(model, "/Users/admin/Downloads/Multi-modal-Fruit-Ripeness-Detection-System/EfficientnetB1.keras")
