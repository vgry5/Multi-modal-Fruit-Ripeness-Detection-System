# %% [markdown]
#  # Fruit Ripeness Detection

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, BatchNormalization, MaxPool2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Model
import os
import matplotlib.pyplot as plt
import glob
import cv2
import seaborn as sns
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
TRAIN_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/train'
VAL_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/val'
TEST_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/test'

# %% [markdown]
# ### Initializing Image Size

# %%
IMAGE_SIZE = (380, 380)
BATCH_SIZE = 16

# %% [markdown]
# ### Initializing train, validation & test data

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(TRAIN_PATH,
                                                   target_size=(IMAGE_SIZE),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 5280 images belonging to 3 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(VAL_PATH,
                                                             target_size=(IMAGE_SIZE),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1320 images belonging to 3 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Over Ripe
# 1 : Ripe
# 2 : Unripe

# %% [markdown]
# ### Plot Images with labels

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
class_num = 3
image_w = 380
image_h = 380

# %% [markdown]
# ### Import model for Transfer Learning

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB4

inputs = layers.Input(shape=(image_w,image_h, 3))

outputs = EfficientNetB4(include_top=True, weights=None, classes=class_num)(inputs)
# Out:
# 2024-03-03 18:13:02.155322: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-03-03 18:13:02.156711: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-03-03 18:13:02.156717: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-03-03 18:13:02.157911: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-03 18:13:02.159782: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"] )

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 380, 380, 3)]     0
#
#  efficientnetb4 (Functional  (None, 3)                 17679202
#  )
#
# =================================================================
# Total params: 17679202 (67.44 MB)
# Trainable params: 17553995 (66.96 MB)
# Non-trainable params: 125207 (489.09 KB)
# _________________________________________________________________

# %%
def learning_rate_schedule(epoch, lr):
    if epoch < 3:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(learning_rate_schedule)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  
    patience=5,          
    restore_best_weights=True, 
)

# %% [markdown]
# ### Train the model

# %%
hist = model.fit(train_generator, validation_data = validation_generator, epochs=50, verbose=2, callbacks = [lr_scheduler,early_stopping])
# Out:
# Epoch 1/50
# 2024-03-03 18:13:12.836231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 330/330 - 619s - loss: 1.8156 - accuracy: 0.5551 - val_loss: 1.4659 - val_accuracy: 0.3333 - lr: 0.0010 - 619s/epoch - 2s/step
# Epoch 2/50
# 330/330 - 532s - loss: 0.6069 - accuracy: 0.7720 - val_loss: 1.6465 - val_accuracy: 0.4091 - lr: 0.0010 - 532s/epoch - 2s/step
# Epoch 3/50
# 330/330 - 536s - loss: 0.4996 - accuracy: 0.8144 - val_loss: 0.4854 - val_accuracy: 0.8583 - lr: 0.0010 - 536s/epoch - 2s/step
# Epoch 4/50
# 330/330 - 531s - loss: 0.3714 - accuracy: 0.8515 - val_loss: 0.3871 - val_accuracy: 0.8159 - lr: 9.0484e-04 - 531s/epoch - 2s/step
# Epoch 5/50
# 330/330 - 533s - loss: 0.3259 - accuracy: 0.8737 - val_loss: 0.2084 - val_accuracy: 0.9394 - lr: 8.1873e-04 - 533s/epoch - 2s/step
# Epoch 6/50
# 330/330 - 534s - loss: 0.2960 - accuracy: 0.8848 - val_loss: 0.3591 - val_accuracy: 0.8591 - lr: 7.4082e-04 - 534s/epoch - 2s/step
# Epoch 7/50
# 330/330 - 531s - loss: 0.2574 - accuracy: 0.8991 - val_loss: 0.2249 - val_accuracy: 0.9280 - lr: 6.7032e-04 - 531s/epoch - 2s/step
# Epoch 8/50
# 330/330 - 520s - loss: 0.2463 - accuracy: 0.9059 - val_loss: 0.2039 - val_accuracy: 0.9167 - lr: 6.0653e-04 - 520s/epoch - 2s/step
# Epoch 9/50
# 330/330 - 528s - loss: 0.2596 - accuracy: 0.9008 - val_loss: 0.1732 - val_accuracy: 0.9348 - lr: 5.4881e-04 - 528s/epoch - 2s/step
# Epoch 10/50
# 330/330 - 523s - loss: 0.2275 - accuracy: 0.9112 - val_loss: 0.2365 - val_accuracy: 0.8962 - lr: 4.9659e-04 - 523s/epoch - 2s/step
# Epoch 11/50
# 330/330 - 545s - loss: 0.2308 - accuracy: 0.9066 - val_loss: 0.2543 - val_accuracy: 0.8955 - lr: 4.4933e-04 - 545s/epoch - 2s/step
# Epoch 12/50
# 330/330 - 545s - loss: 0.2245 - accuracy: 0.9078 - val_loss: 0.1836 - val_accuracy: 0.9439 - lr: 4.0657e-04 - 545s/epoch - 2s/step
# Epoch 13/50
# 330/330 - 543s - loss: 0.1992 - accuracy: 0.9174 - val_loss: 0.1812 - val_accuracy: 0.9621 - lr: 3.6788e-04 - 543s/epoch - 2s/step
# Epoch 14/50
# 330/330 - 543s - loss: 0.2017 - accuracy: 0.9152 - val_loss: 0.1429 - val_accuracy: 0.9432 - lr: 3.3287e-04 - 543s/epoch - 2s/step
# Epoch 15/50
# 330/330 - 543s - loss: 0.1798 - accuracy: 0.9210 - val_loss: 0.1470 - val_accuracy: 0.9530 - lr: 3.0119e-04 - 543s/epoch - 2s/step
# Epoch 16/50
# 330/330 - 546s - loss: 0.1694 - accuracy: 0.9246 - val_loss: 0.1908 - val_accuracy: 0.9114 - lr: 2.7253e-04 - 546s/epoch - 2s/step
# Epoch 17/50
# 330/330 - 554s - loss: 0.1707 - accuracy: 0.9239 - val_loss: 0.1344 - val_accuracy: 0.9492 - lr: 2.4660e-04 - 554s/epoch - 2s/step
# Epoch 18/50
# 330/330 - 558s - loss: 0.1530 - accuracy: 0.9312 - val_loss: 0.1538 - val_accuracy: 0.9371 - lr: 2.2313e-04 - 558s/epoch - 2s/step
# Epoch 19/50
# 330/330 - 544s - loss: 0.1624 - accuracy: 0.9282 - val_loss: 0.1541 - val_accuracy: 0.9394 - lr: 2.0190e-04 - 544s/epoch - 2s/step
# Epoch 20/50
# 330/330 - 556s - loss: 0.1600 - accuracy: 0.9307 - val_loss: 0.2165 - val_accuracy: 0.9000 - lr: 1.8268e-04 - 556s/epoch - 2s/step
# Epoch 21/50
# 330/330 - 520s - loss: 0.1444 - accuracy: 0.9369 - val_loss: 0.0756 - val_accuracy: 0.9803 - lr: 1.6530e-04 - 520s/epoch - 2s/step
# Epoch 22/50
# 330/330 - 524s - loss: 0.1383 - accuracy: 0.9413 - val_loss: 0.1022 - val_accuracy: 0.9689 - lr: 1.4957e-04 - 524s/epoch - 2s/step
# Epoch 23/50

# %% [markdown]
# ### Train, Validation & Test accuracy from saved model

# %%
train_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

train_loss = hist.history['loss']
val_loss = hist.history['val_loss']

learning_rate = hist.history['lr']

# %% [markdown]
# ### Plot Accuracy & Loss graphs

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predictions on Test data

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(TEST_PATH,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMAGE_SIZE),
                                                 class_mode='categorical')

# %%
predictions = model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %% [markdown]
# ### F1- Score, Precision & Recall

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)

# %% [markdown]
# ### Confusion Matrix

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(5,5))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_true, y_pred, target_names=labels.values()))

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(4):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(TEST_PATH, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()

# %%
tf.keras.models.save_model(model, "/Users/admin/Downloads/Multi-modal-Fruit-Ripeness-Detection-System/EfficientnetB4.keras")
