# %% [markdown]
#  # Fruit Ripeness Detection

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, BatchNormalization, MaxPool2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Model
import os
import matplotlib.pyplot as plt
import glob
import cv2
import seaborn as sns
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
TRAIN_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/train'
VAL_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/val'
TEST_PATH = '/Users/admin/Downloads/DSGP/Fruit Dataset_S/test'

# %% [markdown]
# ### Initializing Image Size

# %%
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

# %% [markdown]
# ### Initializing train, validation & test data

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(TRAIN_PATH,
                                                   target_size=(IMAGE_SIZE),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 5280 images belonging to 3 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(VAL_PATH,
                                                             target_size=(IMAGE_SIZE),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1320 images belonging to 3 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Over Ripe
# 1 : Ripe
# 2 : Unripe

# %% [markdown]
# ### Plot Images with labels

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
class_num = 3
image_w = 224
image_h = 224

# %% [markdown]
# ### Import model for Transfer Learning

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB5

inputs = layers.Input(shape=(image_w,image_h, 3))

outputs = EfficientNetB5(include_top=True, weights=None, classes=class_num)(inputs)

# %%
model = tf.keras.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"] )

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb5 (Functional  (None, 3)                 28519674
#  )
#
# =================================================================
# Total params: 28519674 (108.79 MB)
# Trainable params: 28346931 (108.13 MB)
# Non-trainable params: 172743 (674.78 KB)
# _________________________________________________________________

# %%
def learning_rate_schedule(epoch, lr):
    if epoch < 3:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(learning_rate_schedule)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  
    patience=5,          
    restore_best_weights=True, 
)

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_eff.png',show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Train the model

# %%
hist = model.fit(train_generator, validation_data = validation_generator, epochs=50, verbose=2, callbacks = [lr_scheduler,early_stopping])
# Out:
# Epoch 1/50
# 165/165 - 307s - loss: 3.0413 - accuracy: 0.3907 - val_loss: 1.1645 - val_accuracy: 0.3333 - lr: 0.0010 - 307s/epoch - 2s/step
# Epoch 2/50
# 165/165 - 261s - loss: 1.1908 - accuracy: 0.5831 - val_loss: 1.7060 - val_accuracy: 0.3333 - lr: 0.0010 - 261s/epoch - 2s/step
# Epoch 3/50
# 165/165 - 259s - loss: 0.9098 - accuracy: 0.6278 - val_loss: 3.0798 - val_accuracy: 0.5030 - lr: 0.0010 - 259s/epoch - 2s/step
# Epoch 4/50
# 165/165 - 261s - loss: 0.5550 - accuracy: 0.7358 - val_loss: 0.7730 - val_accuracy: 0.6629 - lr: 9.0484e-04 - 261s/epoch - 2s/step
# Epoch 5/50
# 165/165 - 258s - loss: 0.4287 - accuracy: 0.8239 - val_loss: 0.4725 - val_accuracy: 0.8053 - lr: 8.1873e-04 - 258s/epoch - 2s/step
# Epoch 6/50
# 165/165 - 265s - loss: 0.3427 - accuracy: 0.8612 - val_loss: 0.5212 - val_accuracy: 0.7992 - lr: 7.4082e-04 - 265s/epoch - 2s/step
# Epoch 7/50
# 165/165 - 274s - loss: 0.3333 - accuracy: 0.8676 - val_loss: 0.4023 - val_accuracy: 0.8402 - lr: 6.7032e-04 - 274s/epoch - 2s/step
# Epoch 8/50
# 165/165 - 269s - loss: 0.2716 - accuracy: 0.8922 - val_loss: 0.4065 - val_accuracy: 0.8515 - lr: 6.0653e-04 - 269s/epoch - 2s/step
# Epoch 9/50
# 165/165 - 270s - loss: 0.2704 - accuracy: 0.8983 - val_loss: 0.2331 - val_accuracy: 0.9205 - lr: 5.4881e-04 - 270s/epoch - 2s/step
# Epoch 10/50
# 165/165 - 251s - loss: 0.2454 - accuracy: 0.9083 - val_loss: 0.2236 - val_accuracy: 0.9280 - lr: 4.9659e-04 - 251s/epoch - 2s/step
# Epoch 11/50
# 165/165 - 252s - loss: 0.2173 - accuracy: 0.9187 - val_loss: 0.2422 - val_accuracy: 0.9250 - lr: 4.4933e-04 - 252s/epoch - 2s/step
# Epoch 12/50
# 165/165 - 256s - loss: 0.2089 - accuracy: 0.9191 - val_loss: 0.2454 - val_accuracy: 0.9189 - lr: 4.0657e-04 - 256s/epoch - 2s/step
# Epoch 13/50
# 165/165 - 266s - loss: 0.1946 - accuracy: 0.9286 - val_loss: 0.2057 - val_accuracy: 0.9311 - lr: 3.6788e-04 - 266s/epoch - 2s/step
# Epoch 14/50
# 165/165 - 268s - loss: 0.1798 - accuracy: 0.9295 - val_loss: 0.2626 - val_accuracy: 0.9205 - lr: 3.3287e-04 - 268s/epoch - 2s/step
# Epoch 15/50
# 165/165 - 280s - loss: 0.1737 - accuracy: 0.9337 - val_loss: 0.2830 - val_accuracy: 0.9144 - lr: 3.0119e-04 - 280s/epoch - 2s/step
# Epoch 16/50
# 165/165 - 279s - loss: 0.1772 - accuracy: 0.9331 - val_loss: 0.2153 - val_accuracy: 0.9379 - lr: 2.7253e-04 - 279s/epoch - 2s/step
# Epoch 17/50
# 165/165 - 279s - loss: 0.1641 - accuracy: 0.9356 - val_loss: 0.2119 - val_accuracy: 0.9197 - lr: 2.4660e-04 - 279s/epoch - 2s/step
# Epoch 18/50
# 165/165 - 278s - loss: 0.1579 - accuracy: 0.9392 - val_loss: 0.2147 - val_accuracy: 0.9295 - lr: 2.2313e-04 - 278s/epoch - 2s/step

# %% [markdown]
# ### Train, Validation & Test accuracy from saved model

# %%
train_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

train_loss = hist.history['loss']
val_loss = hist.history['val_loss']

learning_rate = hist.history['lr']

# %% [markdown]
# ### Plot Accuracy & Loss graphs

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predictions on Test data

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(TEST_PATH,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMAGE_SIZE),
                                                 class_mode='categorical')
# Out:
# Found 660 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator)
# Out:
# 21/21 [==============================] - 15s 555ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %% [markdown]
# ### F1- Score, Precision & Recall

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 21/21 [==============================] - 16s 795ms/step - loss: 0.2073 - accuracy: 0.9333

# %% [markdown]
# ### Confusion Matrix

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.20727846026420593
# Test Accuracy: 0.9333333373069763

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(5,5))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    Over Ripe       0.96      0.90      0.93       220
#         Ripe       0.86      0.97      0.91       220
#       Unripe       0.99      0.93      0.96       220
#
#     accuracy                           0.93       660
#    macro avg       0.94      0.93      0.93       660
# weighted avg       0.94      0.93      0.93       660

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(4):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(TEST_PATH, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
